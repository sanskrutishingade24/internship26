# %%
#string

# %%
name = "SANSKRUTI"

# %%
name.lower()
# Out:
# 'sanskruti'

# %%
name
# Out:
# 'SANSKRUTI'

# %%
ch = "Hiii"

# %%
ch.swapcase()
# Out:
# 'hIII'

# %%
name.islower()
# Out:
# False

# %%
ch.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "0k123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name.startswith("o")
# Out:
# False

# %%
name1.startswith("o")
# Out:
# True

# %%
city = "pune"

# %%
city.startswith("pune")
# Out:
# True

# %%
c = " pcp "

# %%
c.rstrip()
# Out:
# ' pcp'

# %%
c.lstrip()
# Out:
# 'pcp '

# %%
c.strip()
# Out:
# 'pcp'

# %%
len(c)
# Out:
# 5

# %%
city.replace('u','oo')
# Out:
# 'poone'

# %%
# arithmetic

# %%
a = 5
b = 17

# %%
a+b
# Out:
# 22

# %%
a-b
# Out:
# -12

# %%
a/b
# Out:
# 0.29411764705882354

# %%
b/a
# Out:
# 3.4

# %%
a*b
# Out:
# 85

# %%
a**b
# Out:
# 762939453125

# %%
a//b
# Out:
# 0

# %%
b%a
# Out:
# 2

# %%
# assignment operator

# %%
z = 5

# %%
z = z+3
z
# Out:
# 8

# %%
z += 3
z
# Out:
# 11

# %%
z -= 5
z
# Out:
# 6

# %%
a>b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
c = 4
d = 4

# %%
id(c),id(d)
# Out:
# (11645448, 11645448)

# %%
c is d
# Out:
# True

# %%
c = [1,2]
d = [1,2]

# %%
id(c),id(d)
# Out:
# (137348445269440, 137348445317568)

# %%
c is d
# Out:
# False

# %%
c is not d
# Out:
# True

# %%
z = c

# %%
z is c
# Out:
# True

# %%
z
# Out:
# [1, 2]

# %%
c.append(10)

# %%
c
# Out:
# [1, 2, 10]

# %%
5+2-10
# Out:
# -3

# %%
2 ** 2**3
# Out:
# 256

# %%
name = "Geet"
marks = 76.25

# %%
print("my name is",name)
# Out:
# my name is Geet

# %%
print ("my name is ",name,"and marks are",marks)
# Out:
# my name is  Geet and marks are 76.25

# %%
print("my name is %s and marks are %i" %(name,marks))
# Out:
# my name is Geet and marks are 76

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Geet and marks are 76.25

# %%
# dir and help

# %%
name
# Out:
# 'Geet'

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
help(name.zfill)
# Out:
# Help on built-in function zfill:
#
# zfill(width, /) method of builtins.str instance
#     Pad a numeric string with zeros on the left, to fill a field of the given width.
#
#     The string is never truncated.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(8)
# Out:
# '\x08'

# %%
chr(35)
# Out:
# '#'

# %%
chr(25)
# Out:
# '\x19'

# %%
#typecasting

# %%
num1 =34
num2 = 44.56
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_943/580089627.py in <cell line: 0>()
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
# user i/p

# %%
a = input("enter the number")

# %%
a = int(input("enter the number1 "))
b = int(input("enter the number2 "))

# %%
c = a+b
c

# %%
second = int(input("enter the time in sec "))

# %%
hrs = second // 3600
min = (second % 3600) // 60
second = second % 60

# %%
print(f"{hrs}:{min}:{second}")
# Out:
# 0:7:45
