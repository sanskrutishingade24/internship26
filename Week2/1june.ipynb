# %%
#list

# %%
l = [23,24,25,15,21,]

# %%
print(l)
# Out:
# [23, 24, 25, 15, 21]

# %%
l2 = [12, 34, 56, 12, "sanskruti", 54]

# %%
print(l2)
# Out:
# [12, 34, 56, 12, 'sanskruti', 54]

# %%
l2[3]
# Out:
# 12

# %%
l2[-1]
# Out:
# 54

# %%
#list are mutable

# %%
l2[1]=42

# %%
l2
# Out:
# [12, 42, 56, 12, 'sanskruti', 54]

# %%
l2[-2] = "python"
l2
# Out:
# [12, 42, 56, 12, 'python', 54]

# %%
l3 = [12,3,67,90,'python',98]

# %%
l3
# Out:
# [12, 3, 67, 90, 'python', 98]

# %%
l3[1:3]
# Out:
# [3, 67]

# %%
l3[0:5]
# Out:
# [12, 3, 67, 90, 'python']

# %%
l3[0:6:2]
# Out:
# [12, 67, 'python']

# %%
l3[::1]
# Out:
# [12, 3, 67, 90, 'python', 98]

# %%
l3[-1:0]
# Out:
# []

# %%
l3[::-1]
# Out:
# [98, 'python', 90, 67, 3, 12]

# %%
l3[1:4]=[100,200,300]

# %%
l3
# Out:
# [12, 100, 200, 300, 'python', 98]

# %%
del l2[-2]

# %%
l3
# Out:
# [12, 100, 200, 300, 'python', 98]

# %%
l3[-2]
# Out:
# 'python'

# %%
l3
# Out:
# [12, 100, 200, 300, 'python', 98]

# %%
del l3[-2]
l3
# Out:
# [12, 100, 200, 300, 98]

# %%
l3*2
# Out:
# [12, 100, 200, 300, 98, 12, 100, 200, 300, 98]

# %%
l3+[93,20,29]
# Out:
# [12, 100, 200, 300, 98, 93, 20, 29]

# %%
l2+l3
# Out:
# [12, 42, 56, 12, 54, 12, 100, 200, 300, 98]

# %%
for i in l3:
  print(i**2,end = ' ')
# Out:
# 144 10000 40000 90000 9604

# %%
for i in l4:
  if i%2==1:
    print(i, end = ' ')
# Out:
# 3 5 67

# %%
l2
# Out:
# [12, 42, 56, 12, 54]

# %%
l4 = [3,5,98,67,98]

# %%
newl = [i**2 for i in l4]

# %%
newl
# Out:
# [9, 25, 9604, 4489, 9604]
